# %% [markdown]
# ### Importando as libs

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# ### Conectando com o banco de dados

# %%
# Criar o banco [ Caso exista faz a conexao else conecta no banco ]
conexao_banco = sqlite3.connect('BD_Attrition.db')

# %% [markdown]
# ### Query para acessar a tabela de consultas

# %%
# Consultando o bando de dados
consulta = pd.read_sql_query("""
SELECT * FROM consulta
""", conexao_banco)
consulta.tail()
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 1321   44  Travel_Frequently        429  Research & Development
# 1322   38  Travel_Frequently        508  Research & Development
# 1323   27      Travel_Rarely        155  Research & Development
# 1324   33      Travel_Rarely        813  Research & Development
# 1325   36      Travel_Rarely        852  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 1321                 1          2        Medical                        3
# 1322                 6          4  Life Sciences                        1
# 1323                 4          3  Life Sciences                        2
# 1324                14          3        Medical                        3
# 1325                 5          4  Life Sciences                        2
#
#       Gender  HourlyRate  ...  YearsWithCurrManager  Attrition  \
# 1321       1          99  ...                     3          0
# ...

# %% [markdown]
# ### Query para acessar a tabela de registro de usuários

# %%
# Consultando o bando de dados
pd.read_sql_query("""
SELECT * FROM dados_login
""", conexao_banco)
# Out:
#                E-mail                                              Senha
# 0   teste1@blabla.com  15e2b0d3c33891ebb0f1ef609ec419420c20e320ce94c6...
# 1  teste2@hotmail.com  15e2b0d3c33891ebb0f1ef609ec419420c20e320ce94c6...
# 2  teste3@hotmail.com  ef797c8118f02dfb649607dd5d3f8c7623048c9c063d53...

# %% [markdown]
# ### Finalizando a conexão com o banco de dados

# %%
conexao_banco.close()
